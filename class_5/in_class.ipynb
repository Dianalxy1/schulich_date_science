# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('/Users/xinyuanliang/Desktop/MBAN 6110/module_5_feature_engineering_inclass.csv')
df
# Out:
#      user_id  age       signup_date last_purchase_date  total_purchases  \
# 0          1   33  1978-11-01 17:03    2020-05-11 4:13               10
# 1          2   32  2016-04-08 14:19    1959-01-07 5:45                2
# 2          3   19   2021-03-08 7:01   2006-10-29 16:56                6
# 3          4   48  2006-01-11 11:04   1966-07-01 20:22                8
# 4          5   75   1985-06-16 1:41   2013-05-14 12:44                3
# ..       ...  ...               ...                ...              ...
# 995      996   69   1994-01-02 1:26    2002-12-06 1:07               48
# 996      997   35  1957-10-19 19:41    1977-07-19 0:45               45
# 997      998   49   1970-01-23 0:10    1986-11-01 4:45               38
# 998      999   61  2016-02-26 21:04   1952-01-11 10:28               12
# 999     1000   50   1982-02-02 7:25   2010-04-24 10:07               30
#
#      total_spent favorite_product_category               location  gender  \
# ...

# %%
df.head()
# Out:
#    user_id  age       signup_date last_purchase_date  total_purchases  \
# 0        1   33  1978-11-01 17:03    2020-05-11 4:13               10
# 1        2   32  2016-04-08 14:19    1959-01-07 5:45                2
# 2        3   19   2021-03-08 7:01   2006-10-29 16:56                6
# 3        4   48  2006-01-11 11:04   1966-07-01 20:22                8
# 4        5   75   1985-06-16 1:41   2013-05-14 12:44                3
#
#    total_spent favorite_product_category           location  gender  \
# 0   840.954993                     books        Lake Gerald  female
# 1  1147.412095                     books  North Justinburgh    male
# 2  1301.284835                     books          West Alec  female
# 3  1404.261405                     books            Annaton    male
# 4  1968.752964                     books     East Markburgh  female
#
#   email_domain
# 0    gmail.com
# 1    yahoo.com
# 2    yahoo.com
# 3  hotmail.com
# 4    yahoo.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   user_id                    1000 non-null   int64
#  1   age                        1000 non-null   int64
#  2   signup_date                1000 non-null   object
#  3   last_purchase_date         1000 non-null   object
#  4   total_purchases            1000 non-null   int64
#  5   total_spent                1000 non-null   float64
#  6   favorite_product_category  1000 non-null   object
#  7   location                   1000 non-null   object
#  8   gender                     1000 non-null   object
#  9   email_domain               1000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 78.2+ KB

# %%
df['signup_date']=pd.to_datetime(df['signup_date'])
df['last_purchase_date']=pd.to_datetime(df['last_purchase_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   user_id                    1000 non-null   int64
#  1   age                        1000 non-null   int64
#  2   signup_date                1000 non-null   datetime64[ns]
#  3   last_purchase_date         1000 non-null   datetime64[ns]
#  4   total_purchases            1000 non-null   int64
#  5   total_spent                1000 non-null   float64
#  6   favorite_product_category  0 non-null      float64
#  7   location                   1000 non-null   object
#  8   gender                     1000 non-null   object
#  9   email_domain               1000 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(3), object(3)
# memory usage: 78.2+ KB

# %%
# Dummy variables - convert season to dummies; first - rename season

Favorite_product = {'books':1, 'home': 2, 'electronics':3, 'clothing':4,'beauty':5}
df['favorite_product_category'] = df['favorite_product_category'].map(Favorite_product)
df.head()
# Out:
#    user_id  age         signup_date  last_purchase_date  total_purchases  \
# 0        1   33 1978-11-01 17:03:00 2020-05-11 04:13:00               10
# 1        2   32 2016-04-08 14:19:00 1959-01-07 05:45:00                2
# 2        3   19 2021-03-08 07:01:00 2006-10-29 16:56:00                6
# 3        4   48 2006-01-11 11:04:00 1966-07-01 20:22:00                8
# 4        5   75 1985-06-16 01:41:00 2013-05-14 12:44:00                3
#
#    total_spent  favorite_product_category           location  gender  \
# 0   840.954993                        NaN        Lake Gerald  female
# 1  1147.412095                        NaN  North Justinburgh    male
# 2  1301.284835                        NaN          West Alec  female
# 3  1404.261405                        NaN            Annaton    male
# 4  1968.752964                        NaN     East Markburgh  female
#
#   email_domain
# 0    gmail.com
# 1    yahoo.com
# 2    yahoo.com
# 3  hotmail.com
# 4    yahoo.com

# %%
# Create function to classify amounts
def favorite_product(x):
    if x == 'books':
        return 1
    elif x == 'home':
        return 2
    elif x == 'electronic':
        return 3
    elif x== 'clothing':
        return 4
    else:
        return 5

# %%
scaler = StandardScaler()
df_std = scaler.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 scaler = StandardScaler()
#       2 df_std = scaler.fit_transform(df)
#
# NameError: name 'StandardScaler' is not defined
