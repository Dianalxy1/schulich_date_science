# %%
import sqlalchemy as sa
import pandas as pd
import requests, json

# %% [markdown]
# URL to pull data should look like this:
#
# https://data.ontario.ca/api/3/action/datastore_search?resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=5

# %%
# Specify the data source, resource_id is the data from the website

# this is the part where you go to data.ontario.ca, then search for 'Status of COVID-19 cases in Ontario'
# then find the 'preview English' button for 'Status of COVID-19 cases in Ontario' to check the CSV file of that data,
# then you will see 'Use the data API' or 'the API', that's where you could find the resource_id
# for example: if the query example is like the following: 
# 'https://data.ontario.ca/api/3/action/datastore_search?resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=5'
# then you just have to pick out the strings in between the resource_id= and &limit=5. That is your resource_id
# limit = 500 means we only fetch 500 records from the source website dataset.
# The api_url is where you just copy the query link, in our case, it will look like the following:
# 'https://data.ontario.ca/api/3/action/datastore_search', then add ?resource={}&limit={}.format(resurce_id,limit)
# Just follow the code below!
resource_id = 'ed270bb8-340b-41f9-a7c6-e8ef587e6d11' 
limit=500
api_url = 'https://data.ontario.ca/api/3/action/datastore_search?resource_id={}&limit={}'.format(resource_id, limit)

print(api_url)
# Out:
# https://data.ontario.ca/api/3/action/datastore_search?resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=500

# %%
# Get the data from the source of website
data = requests.get(api_url)

# %%
data
# Out:
# <Response [200]>

# %%
# Store the data into the notebook using json statement
data = data.json()
data
# Out:
# {'help': 'https://data.ontario.ca/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 500,
#   'records_format': 'objects',
#   'resource_id': 'ed270bb8-340b-41f9-a7c6-e8ef587e6d11',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'Reported Date': '2020-02-06T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 1,
#     'Confirmed Positive': None,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': None,
#     'Total patients approved for testing as of Reporting Date': None,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 9,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 2,
#     'Reported Date': '2020-02-07T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 2,
#     'Confirmed Positive': None,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': None,
#     'Total patients approved for testing as of Reporting Date': None,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 19,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 3,
#     'Reported Date': '2020-02-08T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 1,
#     'Confirmed Positive': 1,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 1,
#     'Total patients approved for testing as of Reporting Date': None,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 11,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 4,
#     'Reported Date': '2020-02-09T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 2,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 2,
#     'Total patients approved for testing as of Reporting Date': None,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 27,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 5,
#     'Reported Date': '2020-02-10T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 2,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 2,
#     'Total patients approved for testing as of Reporting Date': None,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 17,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 6,
#     'Reported Date': '2020-02-11T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 3,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': None,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 29,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 7,
#     'Reported Date': '2020-02-12T00:00:00',
#     'Confirmed Negative': 90,
#     'Presumptive Negative': 12,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 3,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 139,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 34,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 8,
#     'Reported Date': '2020-02-13T00:00:00',
#     'Confirmed Negative': 96,
#     'Presumptive Negative': 8,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 3,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 150,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 43,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 9,
#     'Reported Date': '2020-02-14T00:00:00',
#     'Confirmed Negative': 104,
#     'Presumptive Negative': 0,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 3,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 169,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 62,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 10,
#     'Reported Date': '2020-02-15T00:00:00',
#     'Confirmed Negative': 130,
#     'Presumptive Negative': 25,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 3,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 197,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 39,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 11,
#     'Reported Date': '2020-02-16T00:00:00',
#     'Confirmed Negative': 167,
#     'Presumptive Negative': 81,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 3,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 259,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 8,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 12,
#     'Reported Date': '2020-02-17T00:00:00',
#     'Confirmed Negative': 184,
#     'Presumptive Negative': 79,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 3,
#     'Resolved': None,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 285,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 19,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 13,
#     'Reported Date': '2020-02-18T00:00:00',
#     'Confirmed Negative': 257,
#     'Presumptive Negative': 44,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 2,
#     'Resolved': 1,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 313,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 9,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 14,
#     'Reported Date': '2020-02-19T00:00:00',
#     'Confirmed Negative': 306,
#     'Presumptive Negative': 16,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 2,
#     'Resolved': 1,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 340,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 15,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 15,
#     'Reported Date': '2020-02-20T00:00:00',
#     'Confirmed Negative': 353,
#     'Presumptive Negative': 0,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 2,
#     'Resolved': 1,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 364,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 8,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 16,
#     'Reported Date': '2020-02-21T00:00:00',
#     'Confirmed Negative': 399,
#     'Presumptive Negative': 0,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 2,
#     'Resolved': 1,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 402,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 0,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 17,
#     'Reported Date': '2020-02-22T00:00:00',
#     'Confirmed Negative': 418,
#     'Presumptive Negative': 0,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 2,
#     'Resolved': 1,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 421,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 0,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 18,
#     'Reported Date': '2020-02-23T00:00:00',
#     'Confirmed Negative': 436,
#     'Presumptive Negative': 0,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 2,
#     'Resolved': 1,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 456,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 17,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 19,
#     'Reported Date': '2020-02-24T00:00:00',
#     'Confirmed Negative': 462,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 1,
#     'Resolved': 2,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 479,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 14,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 20,
#     'Reported Date': '2020-02-25T00:00:00',
#     'Confirmed Negative': 483,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 0,
#     'Resolved': 3,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 3,
#     'Total patients approved for testing as of Reporting Date': 498,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 12,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 21,
#     'Reported Date': '2020-02-26T00:00:00',
#     'Confirmed Negative': 540,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 1,
#     'Resolved': 3,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 4,
#     'Total patients approved for testing as of Reporting Date': 553,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 9,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 22,
#     'Reported Date': '2020-02-27T00:00:00',
#     'Confirmed Negative': 568,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 0,
#     'Confirmed Positive': 1,
#     'Resolved': 3,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 4,
#     'Total patients approved for testing as of Reporting Date': 593,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 21,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 23,
#     'Reported Date': '2020-02-28T00:00:00',
#     'Confirmed Negative': 610,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 1,
#     'Confirmed Positive': 1,
#     'Resolved': 3,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 4,
#     'Total patients approved for testing as of Reporting Date': 629,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 14,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 24,
#     'Reported Date': '2020-02-29T00:00:00',
#     'Confirmed Negative': 672,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 1,
#     'Confirmed Positive': 2,
#     'Resolved': 3,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 5,
#     'Total patients approved for testing as of Reporting Date': 699,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 21,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 25,
#     'Reported Date': '2020-03-01T00:00:00',
#     'Confirmed Negative': 739,
#     'Presumptive Negative': None,
#     'Presumptive Positive': 1,
#     'Confirmed Positive': 3,
#     'Resolved': 3,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 6,
#     'Total patients approved for testing as of Reporting Date': 768,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 22,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 26,
#     'Reported Date': '2020-03-02T00:00:00',
#     'Confirmed Negative': 975,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 15,
#     'Resolved': 3,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 18,
#     'Total patients approved for testing as of Reporting Date': 1005,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 12,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 27,
#     'Reported Date': '2020-03-03T00:00:00',
#     'Confirmed Negative': 1061,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 17,
#     'Resolved': 3,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 20,
#     'Total patients approved for testing as of Reporting Date': 1126,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 45,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 28,
#     'Reported Date': '2020-03-04T00:00:00',
#     'Confirmed Negative': 1216,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 17,
#     'Resolved': 3,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 20,
#     'Total patients approved for testing as of Reporting Date': 1338,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 102,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 29,
#     'Reported Date': '2020-03-05T00:00:00',
#     'Confirmed Negative': 1466,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 18,
#     'Resolved': 4,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 22,
#     'Total patients approved for testing as of Reporting Date': 1566,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 78,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 30,
#     'Reported Date': '2020-03-06T00:00:00',
#     'Confirmed Negative': 1665,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 22,
#     'Resolved': 4,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 26,
#     'Total patients approved for testing as of Reporting Date': 1763,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 72,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 31,
#     'Reported Date': '2020-03-07T00:00:00',
#     'Confirmed Negative': 1918,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 24,
#     'Resolved': 4,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 28,
#     'Total patients approved for testing as of Reporting Date': 1982,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 36,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 32,
#     'Reported Date': '2020-03-08T00:00:00',
#     'Confirmed Negative': 2094,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 25,
#     'Resolved': 4,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 29,
#     'Total patients approved for testing as of Reporting Date': 2178,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 55,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 33,
#     'Reported Date': '2020-03-09T00:00:00',
#     'Confirmed Negative': 2347,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 31,
#     'Resolved': 4,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 35,
#     'Total patients approved for testing as of Reporting Date': 2404,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 22,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 34,
#     'Reported Date': '2020-03-10T00:00:00',
#     'Confirmed Negative': 2599,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 31,
#     'Resolved': 5,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 36,
#     'Total patients approved for testing as of Reporting Date': 2747,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 112,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 35,
#     'Reported Date': '2020-03-11T00:00:00',
#     'Confirmed Negative': 2888,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 37,
#     'Resolved': 5,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 42,
#     'Total patients approved for testing as of Reporting Date': 3395,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 465,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
#     'Number of patients in ICU on a ventilator due to COVID-19': None,
#     'Num. of patients in ICU on a ventilator testing positive': None,
#     'Num. of patients in ICU on a ventilator testing negative': None,
#     'Total Positive LTC Resident Cases': None,
#     'Total Positive LTC HCW Cases': None,
#     'Total LTC Resident Deaths': None,
#     'Total LTC HCW Deaths': None,
#     'Total_Lineage_B.1.1.7_Alpha': None,
#     'Total_Lineage_B.1.351_Beta': None,
#     'Total_Lineage_P.1_Gamma': None,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 36,
#     'Reported Date': '2020-03-12T00:00:00',
#     'Confirmed Negative': 3590,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 54,
#     'Resolved': 5,
#     'Deaths': None,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 59,
#     'Total patients approved for testing as of Reporting Date': 4185,
#     'Total tests completed in the last day': None,
#     'Percent positive tests in last day': None,
#     'Under Investigation': 536,
#     'Number of patients hospitalized with COVID-19': None,
#     'Number of patients in ICU due to COVID-19': None,
#     'Number of patients in ICU, testing positive for COVID-19': None,
#     'Number of patients in ICU, testing negative for COVID-19': None,
# ...
#     'Number of patients in ICU, testing positive for COVID-19': 366,
#     'Number of patients in ICU, testing negative for COVID-19': 74,
#     'Number of patients in ICU on a ventilator due to COVID-19': 292,
#     'Num. of patients in ICU on a ventilator testing positive': 258,
#     'Num. of patients in ICU on a ventilator testing negative': 34,
#     'Total Positive LTC Resident Cases': 15322,
#     'Total Positive LTC HCW Cases': 7116,
#     'Total LTC Resident Deaths': 3961,
#     'Total LTC HCW Deaths': 10,
#     'Total_Lineage_B.1.1.7_Alpha': 137307,
#     'Total_Lineage_B.1.351_Beta': 1128,
#     'Total_Lineage_P.1_Gamma': 4099,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 493,
#     'Reported Date': '2021-06-12T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 5841,
#     'Resolved': 524362,
#     'Deaths': 8950,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 539153,
#     'Total patients approved for testing as of Reporting Date': 15539361,
#     'Total tests completed in the last day': 24099,
#     'Percent positive tests in last day': 2.1,
#     'Under Investigation': 10338,
#     'Number of patients hospitalized with COVID-19': 447,
#     'Number of patients in ICU due to COVID-19': 422,
#     'Number of patients in ICU, testing positive for COVID-19': 343,
#     'Number of patients in ICU, testing negative for COVID-19': 79,
#     'Number of patients in ICU on a ventilator due to COVID-19': 277,
#     'Num. of patients in ICU on a ventilator testing positive': 239,
#     'Num. of patients in ICU on a ventilator testing negative': 38,
#     'Total Positive LTC Resident Cases': 15325,
#     'Total Positive LTC HCW Cases': 7117,
#     'Total LTC Resident Deaths': 3962,
#     'Total LTC HCW Deaths': 10,
#     'Total_Lineage_B.1.1.7_Alpha': 138697,
#     'Total_Lineage_B.1.351_Beta': 1134,
#     'Total_Lineage_P.1_Gamma': 4124,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 494,
#     'Reported Date': '2021-06-13T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 5601,
#     'Resolved': 525125,
#     'Deaths': 8957,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 539683,
#     'Total patients approved for testing as of Reporting Date': 15560092,
#     'Total tests completed in the last day': 20731,
#     'Percent positive tests in last day': 2.6,
#     'Under Investigation': 5846,
#     'Number of patients hospitalized with COVID-19': 373,
#     'Number of patients in ICU due to COVID-19': 426,
#     'Number of patients in ICU, testing positive for COVID-19': 350,
#     'Number of patients in ICU, testing negative for COVID-19': 76,
#     'Number of patients in ICU on a ventilator due to COVID-19': 273,
#     'Num. of patients in ICU on a ventilator testing positive': 239,
#     'Num. of patients in ICU on a ventilator testing negative': 34,
#     'Total Positive LTC Resident Cases': 15326,
#     'Total Positive LTC HCW Cases': 7117,
#     'Total LTC Resident Deaths': 3963,
#     'Total LTC HCW Deaths': 10,
#     'Total_Lineage_B.1.1.7_Alpha': 139482,
#     'Total_Lineage_B.1.351_Beta': 1137,
#     'Total_Lineage_P.1_Gamma': 4133,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 495,
#     'Reported Date': '2021-06-14T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 5374,
#     'Resolved': 525795,
#     'Deaths': 8961,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 540130,
#     'Total patients approved for testing as of Reporting Date': 15573680,
#     'Total tests completed in the last day': 13588,
#     'Percent positive tests in last day': 2.8,
#     'Under Investigation': 5317,
#     'Number of patients hospitalized with COVID-19': 384,
#     'Number of patients in ICU due to COVID-19': 409,
#     'Number of patients in ICU, testing positive for COVID-19': 340,
#     'Number of patients in ICU, testing negative for COVID-19': 69,
#     'Number of patients in ICU on a ventilator due to COVID-19': 268,
#     'Num. of patients in ICU on a ventilator testing positive': 234,
#     'Num. of patients in ICU on a ventilator testing negative': 34,
#     'Total Positive LTC Resident Cases': 15327,
#     'Total Positive LTC HCW Cases': 7117,
#     'Total LTC Resident Deaths': 3963,
#     'Total LTC HCW Deaths': 10,
#     'Total_Lineage_B.1.1.7_Alpha': 139940,
#     'Total_Lineage_B.1.351_Beta': 1137,
#     'Total_Lineage_P.1_Gamma': 4135,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 496,
#     'Reported Date': '2021-06-15T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 5012,
#     'Resolved': 526440,
#     'Deaths': 8974,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 540426,
#     'Total patients approved for testing as of Reporting Date': 15590842,
#     'Total tests completed in the last day': 17162,
#     'Percent positive tests in last day': 2.3,
#     'Under Investigation': 14236,
#     'Number of patients hospitalized with COVID-19': 433,
#     'Number of patients in ICU due to COVID-19': 382,
#     'Number of patients in ICU, testing positive for COVID-19': 318,
#     'Number of patients in ICU, testing negative for COVID-19': 64,
#     'Number of patients in ICU on a ventilator due to COVID-19': 244,
#     'Num. of patients in ICU on a ventilator testing positive': 215,
#     'Num. of patients in ICU on a ventilator testing negative': 29,
#     'Total Positive LTC Resident Cases': 15332,
#     'Total Positive LTC HCW Cases': 7129,
#     'Total LTC Resident Deaths': 3965,
#     'Total LTC HCW Deaths': 10,
#     'Total_Lineage_B.1.1.7_Alpha': 140618,
#     'Total_Lineage_B.1.351_Beta': 1137,
#     'Total_Lineage_P.1_Gamma': 4137,
#     'Total_Lineage_B.1.617.2_Delta': None,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 497,
#     'Reported Date': '2021-06-16T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 4662,
#     'Resolved': 527162,
#     'Deaths': 8986,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 540810,
#     'Total patients approved for testing as of Reporting Date': 15618918,
#     'Total tests completed in the last day': 28076,
#     'Percent positive tests in last day': 1.5,
#     'Under Investigation': 13336,
#     'Number of patients hospitalized with COVID-19': 438,
#     'Number of patients in ICU due to COVID-19': 377,
#     'Number of patients in ICU, testing positive for COVID-19': 308,
#     'Number of patients in ICU, testing negative for COVID-19': 69,
#     'Number of patients in ICU on a ventilator due to COVID-19': 242,
#     'Num. of patients in ICU on a ventilator testing positive': 211,
#     'Num. of patients in ICU on a ventilator testing negative': 31,
#     'Total Positive LTC Resident Cases': 15332,
#     'Total Positive LTC HCW Cases': 7132,
#     'Total LTC Resident Deaths': 3965,
#     'Total LTC HCW Deaths': 10,
#     'Total_Lineage_B.1.1.7_Alpha': 141106,
#     'Total_Lineage_B.1.351_Beta': 1141,
#     'Total_Lineage_P.1_Gamma': 4156,
#     'Total_Lineage_B.1.617.2_Delta': 497,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 498,
#     'Reported Date': '2021-06-17T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 4390,
#     'Resolved': 527797,
#     'Deaths': 8993,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 541180,
#     'Total patients approved for testing as of Reporting Date': 15649372,
#     'Total tests completed in the last day': 30454,
#     'Percent positive tests in last day': 1.3,
#     'Under Investigation': 11462,
#     'Number of patients hospitalized with COVID-19': 397,
#     'Number of patients in ICU due to COVID-19': 362,
#     'Number of patients in ICU, testing positive for COVID-19': 297,
#     'Number of patients in ICU, testing negative for COVID-19': 65,
#     'Number of patients in ICU on a ventilator due to COVID-19': 232,
#     'Num. of patients in ICU on a ventilator testing positive': 198,
#     'Num. of patients in ICU on a ventilator testing negative': 34,
#     'Total Positive LTC Resident Cases': 15336,
#     'Total Positive LTC HCW Cases': 7133,
#     'Total LTC Resident Deaths': 3965,
#     'Total LTC HCW Deaths': 10,
#     'Total_Lineage_B.1.1.7_Alpha': 141472,
#     'Total_Lineage_B.1.351_Beta': 1144,
#     'Total_Lineage_P.1_Gamma': 4187,
#     'Total_Lineage_B.1.617.2_Delta': 586,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 499,
#     'Reported Date': '2021-06-18T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 4110,
#     'Resolved': 528421,
#     'Deaths': 8994,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 541525,
#     'Total patients approved for testing as of Reporting Date': 15676015,
#     'Total tests completed in the last day': 26643,
#     'Percent positive tests in last day': 1.4,
#     'Under Investigation': 11236,
#     'Number of patients hospitalized with COVID-19': 378,
#     'Number of patients in ICU due to COVID-19': 352,
#     'Number of patients in ICU, testing positive for COVID-19': 293,
#     'Number of patients in ICU, testing negative for COVID-19': 59,
#     'Number of patients in ICU on a ventilator due to COVID-19': 221,
#     'Num. of patients in ICU on a ventilator testing positive': 194,
#     'Num. of patients in ICU on a ventilator testing negative': 27,
#     'Total Positive LTC Resident Cases': 15335,
#     'Total Positive LTC HCW Cases': 7135,
#     'Total LTC Resident Deaths': 3965,
#     'Total LTC HCW Deaths': 10,
#     'Total_Lineage_B.1.1.7_Alpha': 141700,
#     'Total_Lineage_B.1.351_Beta': 1146,
#     'Total_Lineage_P.1_Gamma': 4200,
#     'Total_Lineage_B.1.617.2_Delta': 657,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None},
#    {'_id': 500,
#     'Reported Date': '2021-06-19T00:00:00',
#     'Confirmed Negative': None,
#     'Presumptive Negative': None,
#     'Presumptive Positive': None,
#     'Confirmed Positive': 3871,
#     'Resolved': 529002,
#     'Deaths': 9007,
#     'Deaths_New_Methodology': None,
#     'Total Cases': 541880,
#     'Total patients approved for testing as of Reporting Date': 15701383,
#     'Total tests completed in the last day': 25368,
#     'Percent positive tests in last day': 1.4,
#     'Under Investigation': 9299,
#     'Number of patients hospitalized with COVID-19': 336,
#     'Number of patients in ICU due to COVID-19': 335,
#     'Number of patients in ICU, testing positive for COVID-19': 279,
#     'Number of patients in ICU, testing negative for COVID-19': 56,
#     'Number of patients in ICU on a ventilator due to COVID-19': 221,
#     'Num. of patients in ICU on a ventilator testing positive': 196,
#     'Num. of patients in ICU on a ventilator testing negative': 25,
#     'Total Positive LTC Resident Cases': 15336,
#     'Total Positive LTC HCW Cases': 7135,
#     'Total LTC Resident Deaths': 3965,
#     'Total LTC HCW Deaths': 10,
#     'Total_Lineage_B.1.1.7_Alpha': 141986,
#     'Total_Lineage_B.1.351_Beta': 1154,
#     'Total_Lineage_P.1_Gamma': 4229,
#     'Total_Lineage_B.1.617.2_Delta': 731,
#     'deaths_data_cleaning': None,
#     'newly_reported_deaths': None}],
#   'fields': [{'id': '_id', 'type': 'int'},
#    {'id': 'Reported Date',
#     'type': 'timestamp',
#     'info': {'notes': '', 'type_override': 'timestamp', 'label': ''}},
#    {'id': 'Confirmed Negative',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Presumptive Negative',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Presumptive Positive',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Confirmed Positive',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Resolved',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Deaths',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Deaths_New_Methodology',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total Cases',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total patients approved for testing as of Reporting Date',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total tests completed in the last day',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Percent positive tests in last day',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Under Investigation',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Number of patients hospitalized with COVID-19',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Number of patients in ICU due to COVID-19',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Number of patients in ICU, testing positive for COVID-19',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Number of patients in ICU, testing negative for COVID-19',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Number of patients in ICU on a ventilator due to COVID-19',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Num. of patients in ICU on a ventilator testing positive',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Num. of patients in ICU on a ventilator testing negative',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total Positive LTC Resident Cases',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total Positive LTC HCW Cases',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total LTC Resident Deaths',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total LTC HCW Deaths',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total_Lineage_B.1.1.7_Alpha',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total_Lineage_B.1.351_Beta',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total_Lineage_P.1_Gamma',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'Total_Lineage_B.1.617.2_Delta',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'deaths_data_cleaning',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#    {'id': 'newly_reported_deaths',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}}],
#   '_links': {'start': '/api/3/action/datastore_search?resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=500',
#    'next': '/api/3/action/datastore_search?resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=500&offset=500'},
#   'total': 1151,
#   'total_was_estimated': False}}

# %%
data['help']
# Out:
# 'https://data.ontario.ca/api/3/action/help_show?name=datastore_search'

# %%
data['success']
# Out:
# True

# %%
data['result']
# Out:
# {'include_total': True,
#  'limit': 500,
#  'records_format': 'objects',
#  'resource_id': 'ed270bb8-340b-41f9-a7c6-e8ef587e6d11',
#  'total_estimation_threshold': None,
#  'records': [{'_id': 1,
#    'Reported Date': '2020-02-06T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 1,
#    'Confirmed Positive': None,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': None,
#    'Total patients approved for testing as of Reporting Date': None,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 9,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 2,
#    'Reported Date': '2020-02-07T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 2,
#    'Confirmed Positive': None,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': None,
#    'Total patients approved for testing as of Reporting Date': None,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 19,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 3,
#    'Reported Date': '2020-02-08T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 1,
#    'Confirmed Positive': 1,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 1,
#    'Total patients approved for testing as of Reporting Date': None,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 11,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 4,
#    'Reported Date': '2020-02-09T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 2,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 2,
#    'Total patients approved for testing as of Reporting Date': None,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 27,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 5,
#    'Reported Date': '2020-02-10T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 2,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 2,
#    'Total patients approved for testing as of Reporting Date': None,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 17,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 6,
#    'Reported Date': '2020-02-11T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 3,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': None,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 29,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 7,
#    'Reported Date': '2020-02-12T00:00:00',
#    'Confirmed Negative': 90,
#    'Presumptive Negative': 12,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 3,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 139,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 34,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 8,
#    'Reported Date': '2020-02-13T00:00:00',
#    'Confirmed Negative': 96,
#    'Presumptive Negative': 8,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 3,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 150,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 43,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 9,
#    'Reported Date': '2020-02-14T00:00:00',
#    'Confirmed Negative': 104,
#    'Presumptive Negative': 0,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 3,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 169,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 62,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 10,
#    'Reported Date': '2020-02-15T00:00:00',
#    'Confirmed Negative': 130,
#    'Presumptive Negative': 25,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 3,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 197,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 39,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 11,
#    'Reported Date': '2020-02-16T00:00:00',
#    'Confirmed Negative': 167,
#    'Presumptive Negative': 81,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 3,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 259,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 8,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 12,
#    'Reported Date': '2020-02-17T00:00:00',
#    'Confirmed Negative': 184,
#    'Presumptive Negative': 79,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 3,
#    'Resolved': None,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 285,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 19,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 13,
#    'Reported Date': '2020-02-18T00:00:00',
#    'Confirmed Negative': 257,
#    'Presumptive Negative': 44,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 2,
#    'Resolved': 1,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 313,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 9,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 14,
#    'Reported Date': '2020-02-19T00:00:00',
#    'Confirmed Negative': 306,
#    'Presumptive Negative': 16,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 2,
#    'Resolved': 1,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 340,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 15,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 15,
#    'Reported Date': '2020-02-20T00:00:00',
#    'Confirmed Negative': 353,
#    'Presumptive Negative': 0,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 2,
#    'Resolved': 1,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 364,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 8,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 16,
#    'Reported Date': '2020-02-21T00:00:00',
#    'Confirmed Negative': 399,
#    'Presumptive Negative': 0,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 2,
#    'Resolved': 1,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 402,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 0,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 17,
#    'Reported Date': '2020-02-22T00:00:00',
#    'Confirmed Negative': 418,
#    'Presumptive Negative': 0,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 2,
#    'Resolved': 1,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 421,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 0,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 18,
#    'Reported Date': '2020-02-23T00:00:00',
#    'Confirmed Negative': 436,
#    'Presumptive Negative': 0,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 2,
#    'Resolved': 1,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 456,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 17,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 19,
#    'Reported Date': '2020-02-24T00:00:00',
#    'Confirmed Negative': 462,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 1,
#    'Resolved': 2,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 479,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 14,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 20,
#    'Reported Date': '2020-02-25T00:00:00',
#    'Confirmed Negative': 483,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 0,
#    'Resolved': 3,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 3,
#    'Total patients approved for testing as of Reporting Date': 498,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 12,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 21,
#    'Reported Date': '2020-02-26T00:00:00',
#    'Confirmed Negative': 540,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 1,
#    'Resolved': 3,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 4,
#    'Total patients approved for testing as of Reporting Date': 553,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 9,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 22,
#    'Reported Date': '2020-02-27T00:00:00',
#    'Confirmed Negative': 568,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 0,
#    'Confirmed Positive': 1,
#    'Resolved': 3,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 4,
#    'Total patients approved for testing as of Reporting Date': 593,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 21,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 23,
#    'Reported Date': '2020-02-28T00:00:00',
#    'Confirmed Negative': 610,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 1,
#    'Confirmed Positive': 1,
#    'Resolved': 3,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 4,
#    'Total patients approved for testing as of Reporting Date': 629,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 14,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 24,
#    'Reported Date': '2020-02-29T00:00:00',
#    'Confirmed Negative': 672,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 1,
#    'Confirmed Positive': 2,
#    'Resolved': 3,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 5,
#    'Total patients approved for testing as of Reporting Date': 699,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 21,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 25,
#    'Reported Date': '2020-03-01T00:00:00',
#    'Confirmed Negative': 739,
#    'Presumptive Negative': None,
#    'Presumptive Positive': 1,
#    'Confirmed Positive': 3,
#    'Resolved': 3,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 6,
#    'Total patients approved for testing as of Reporting Date': 768,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 22,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 26,
#    'Reported Date': '2020-03-02T00:00:00',
#    'Confirmed Negative': 975,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 15,
#    'Resolved': 3,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 18,
#    'Total patients approved for testing as of Reporting Date': 1005,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 12,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 27,
#    'Reported Date': '2020-03-03T00:00:00',
#    'Confirmed Negative': 1061,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 17,
#    'Resolved': 3,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 20,
#    'Total patients approved for testing as of Reporting Date': 1126,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 45,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 28,
#    'Reported Date': '2020-03-04T00:00:00',
#    'Confirmed Negative': 1216,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 17,
#    'Resolved': 3,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 20,
#    'Total patients approved for testing as of Reporting Date': 1338,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 102,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 29,
#    'Reported Date': '2020-03-05T00:00:00',
#    'Confirmed Negative': 1466,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 18,
#    'Resolved': 4,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 22,
#    'Total patients approved for testing as of Reporting Date': 1566,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 78,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 30,
#    'Reported Date': '2020-03-06T00:00:00',
#    'Confirmed Negative': 1665,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 22,
#    'Resolved': 4,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 26,
#    'Total patients approved for testing as of Reporting Date': 1763,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 72,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 31,
#    'Reported Date': '2020-03-07T00:00:00',
#    'Confirmed Negative': 1918,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 24,
#    'Resolved': 4,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 28,
#    'Total patients approved for testing as of Reporting Date': 1982,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 36,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 32,
#    'Reported Date': '2020-03-08T00:00:00',
#    'Confirmed Negative': 2094,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 25,
#    'Resolved': 4,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 29,
#    'Total patients approved for testing as of Reporting Date': 2178,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 55,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 33,
#    'Reported Date': '2020-03-09T00:00:00',
#    'Confirmed Negative': 2347,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 31,
#    'Resolved': 4,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 35,
#    'Total patients approved for testing as of Reporting Date': 2404,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 22,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 34,
#    'Reported Date': '2020-03-10T00:00:00',
#    'Confirmed Negative': 2599,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 31,
#    'Resolved': 5,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 36,
#    'Total patients approved for testing as of Reporting Date': 2747,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 112,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 35,
#    'Reported Date': '2020-03-11T00:00:00',
#    'Confirmed Negative': 2888,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 37,
#    'Resolved': 5,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 42,
#    'Total patients approved for testing as of Reporting Date': 3395,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 465,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 36,
#    'Reported Date': '2020-03-12T00:00:00',
#    'Confirmed Negative': 3590,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 54,
#    'Resolved': 5,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 59,
#    'Total patients approved for testing as of Reporting Date': 4185,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 536,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
#    'Number of patients in ICU, testing negative for COVID-19': None,
#    'Number of patients in ICU on a ventilator due to COVID-19': None,
#    'Num. of patients in ICU on a ventilator testing positive': None,
#    'Num. of patients in ICU on a ventilator testing negative': None,
#    'Total Positive LTC Resident Cases': None,
#    'Total Positive LTC HCW Cases': None,
#    'Total LTC Resident Deaths': None,
#    'Total LTC HCW Deaths': None,
#    'Total_Lineage_B.1.1.7_Alpha': None,
#    'Total_Lineage_B.1.351_Beta': None,
#    'Total_Lineage_P.1_Gamma': None,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 37,
#    'Reported Date': '2020-03-13T00:00:00',
#    'Confirmed Negative': 4470,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 74,
#    'Resolved': 5,
#    'Deaths': None,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 79,
#    'Total patients approved for testing as of Reporting Date': 5129,
#    'Total tests completed in the last day': None,
#    'Percent positive tests in last day': None,
#    'Under Investigation': 580,
#    'Number of patients hospitalized with COVID-19': None,
#    'Number of patients in ICU due to COVID-19': None,
#    'Number of patients in ICU, testing positive for COVID-19': None,
# ...
#    'Total Cases': 538651,
#    'Total patients approved for testing as of Reporting Date': 15515262,
#    'Total tests completed in the last day': 28949,
#    'Percent positive tests in last day': 2,
#    'Under Investigation': 10953,
#    'Number of patients hospitalized with COVID-19': 489,
#    'Number of patients in ICU due to COVID-19': 440,
#    'Number of patients in ICU, testing positive for COVID-19': 366,
#    'Number of patients in ICU, testing negative for COVID-19': 74,
#    'Number of patients in ICU on a ventilator due to COVID-19': 292,
#    'Num. of patients in ICU on a ventilator testing positive': 258,
#    'Num. of patients in ICU on a ventilator testing negative': 34,
#    'Total Positive LTC Resident Cases': 15322,
#    'Total Positive LTC HCW Cases': 7116,
#    'Total LTC Resident Deaths': 3961,
#    'Total LTC HCW Deaths': 10,
#    'Total_Lineage_B.1.1.7_Alpha': 137307,
#    'Total_Lineage_B.1.351_Beta': 1128,
#    'Total_Lineage_P.1_Gamma': 4099,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 493,
#    'Reported Date': '2021-06-12T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 5841,
#    'Resolved': 524362,
#    'Deaths': 8950,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 539153,
#    'Total patients approved for testing as of Reporting Date': 15539361,
#    'Total tests completed in the last day': 24099,
#    'Percent positive tests in last day': 2.1,
#    'Under Investigation': 10338,
#    'Number of patients hospitalized with COVID-19': 447,
#    'Number of patients in ICU due to COVID-19': 422,
#    'Number of patients in ICU, testing positive for COVID-19': 343,
#    'Number of patients in ICU, testing negative for COVID-19': 79,
#    'Number of patients in ICU on a ventilator due to COVID-19': 277,
#    'Num. of patients in ICU on a ventilator testing positive': 239,
#    'Num. of patients in ICU on a ventilator testing negative': 38,
#    'Total Positive LTC Resident Cases': 15325,
#    'Total Positive LTC HCW Cases': 7117,
#    'Total LTC Resident Deaths': 3962,
#    'Total LTC HCW Deaths': 10,
#    'Total_Lineage_B.1.1.7_Alpha': 138697,
#    'Total_Lineage_B.1.351_Beta': 1134,
#    'Total_Lineage_P.1_Gamma': 4124,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 494,
#    'Reported Date': '2021-06-13T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 5601,
#    'Resolved': 525125,
#    'Deaths': 8957,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 539683,
#    'Total patients approved for testing as of Reporting Date': 15560092,
#    'Total tests completed in the last day': 20731,
#    'Percent positive tests in last day': 2.6,
#    'Under Investigation': 5846,
#    'Number of patients hospitalized with COVID-19': 373,
#    'Number of patients in ICU due to COVID-19': 426,
#    'Number of patients in ICU, testing positive for COVID-19': 350,
#    'Number of patients in ICU, testing negative for COVID-19': 76,
#    'Number of patients in ICU on a ventilator due to COVID-19': 273,
#    'Num. of patients in ICU on a ventilator testing positive': 239,
#    'Num. of patients in ICU on a ventilator testing negative': 34,
#    'Total Positive LTC Resident Cases': 15326,
#    'Total Positive LTC HCW Cases': 7117,
#    'Total LTC Resident Deaths': 3963,
#    'Total LTC HCW Deaths': 10,
#    'Total_Lineage_B.1.1.7_Alpha': 139482,
#    'Total_Lineage_B.1.351_Beta': 1137,
#    'Total_Lineage_P.1_Gamma': 4133,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 495,
#    'Reported Date': '2021-06-14T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 5374,
#    'Resolved': 525795,
#    'Deaths': 8961,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 540130,
#    'Total patients approved for testing as of Reporting Date': 15573680,
#    'Total tests completed in the last day': 13588,
#    'Percent positive tests in last day': 2.8,
#    'Under Investigation': 5317,
#    'Number of patients hospitalized with COVID-19': 384,
#    'Number of patients in ICU due to COVID-19': 409,
#    'Number of patients in ICU, testing positive for COVID-19': 340,
#    'Number of patients in ICU, testing negative for COVID-19': 69,
#    'Number of patients in ICU on a ventilator due to COVID-19': 268,
#    'Num. of patients in ICU on a ventilator testing positive': 234,
#    'Num. of patients in ICU on a ventilator testing negative': 34,
#    'Total Positive LTC Resident Cases': 15327,
#    'Total Positive LTC HCW Cases': 7117,
#    'Total LTC Resident Deaths': 3963,
#    'Total LTC HCW Deaths': 10,
#    'Total_Lineage_B.1.1.7_Alpha': 139940,
#    'Total_Lineage_B.1.351_Beta': 1137,
#    'Total_Lineage_P.1_Gamma': 4135,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 496,
#    'Reported Date': '2021-06-15T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 5012,
#    'Resolved': 526440,
#    'Deaths': 8974,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 540426,
#    'Total patients approved for testing as of Reporting Date': 15590842,
#    'Total tests completed in the last day': 17162,
#    'Percent positive tests in last day': 2.3,
#    'Under Investigation': 14236,
#    'Number of patients hospitalized with COVID-19': 433,
#    'Number of patients in ICU due to COVID-19': 382,
#    'Number of patients in ICU, testing positive for COVID-19': 318,
#    'Number of patients in ICU, testing negative for COVID-19': 64,
#    'Number of patients in ICU on a ventilator due to COVID-19': 244,
#    'Num. of patients in ICU on a ventilator testing positive': 215,
#    'Num. of patients in ICU on a ventilator testing negative': 29,
#    'Total Positive LTC Resident Cases': 15332,
#    'Total Positive LTC HCW Cases': 7129,
#    'Total LTC Resident Deaths': 3965,
#    'Total LTC HCW Deaths': 10,
#    'Total_Lineage_B.1.1.7_Alpha': 140618,
#    'Total_Lineage_B.1.351_Beta': 1137,
#    'Total_Lineage_P.1_Gamma': 4137,
#    'Total_Lineage_B.1.617.2_Delta': None,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 497,
#    'Reported Date': '2021-06-16T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 4662,
#    'Resolved': 527162,
#    'Deaths': 8986,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 540810,
#    'Total patients approved for testing as of Reporting Date': 15618918,
#    'Total tests completed in the last day': 28076,
#    'Percent positive tests in last day': 1.5,
#    'Under Investigation': 13336,
#    'Number of patients hospitalized with COVID-19': 438,
#    'Number of patients in ICU due to COVID-19': 377,
#    'Number of patients in ICU, testing positive for COVID-19': 308,
#    'Number of patients in ICU, testing negative for COVID-19': 69,
#    'Number of patients in ICU on a ventilator due to COVID-19': 242,
#    'Num. of patients in ICU on a ventilator testing positive': 211,
#    'Num. of patients in ICU on a ventilator testing negative': 31,
#    'Total Positive LTC Resident Cases': 15332,
#    'Total Positive LTC HCW Cases': 7132,
#    'Total LTC Resident Deaths': 3965,
#    'Total LTC HCW Deaths': 10,
#    'Total_Lineage_B.1.1.7_Alpha': 141106,
#    'Total_Lineage_B.1.351_Beta': 1141,
#    'Total_Lineage_P.1_Gamma': 4156,
#    'Total_Lineage_B.1.617.2_Delta': 497,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 498,
#    'Reported Date': '2021-06-17T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 4390,
#    'Resolved': 527797,
#    'Deaths': 8993,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 541180,
#    'Total patients approved for testing as of Reporting Date': 15649372,
#    'Total tests completed in the last day': 30454,
#    'Percent positive tests in last day': 1.3,
#    'Under Investigation': 11462,
#    'Number of patients hospitalized with COVID-19': 397,
#    'Number of patients in ICU due to COVID-19': 362,
#    'Number of patients in ICU, testing positive for COVID-19': 297,
#    'Number of patients in ICU, testing negative for COVID-19': 65,
#    'Number of patients in ICU on a ventilator due to COVID-19': 232,
#    'Num. of patients in ICU on a ventilator testing positive': 198,
#    'Num. of patients in ICU on a ventilator testing negative': 34,
#    'Total Positive LTC Resident Cases': 15336,
#    'Total Positive LTC HCW Cases': 7133,
#    'Total LTC Resident Deaths': 3965,
#    'Total LTC HCW Deaths': 10,
#    'Total_Lineage_B.1.1.7_Alpha': 141472,
#    'Total_Lineage_B.1.351_Beta': 1144,
#    'Total_Lineage_P.1_Gamma': 4187,
#    'Total_Lineage_B.1.617.2_Delta': 586,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 499,
#    'Reported Date': '2021-06-18T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 4110,
#    'Resolved': 528421,
#    'Deaths': 8994,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 541525,
#    'Total patients approved for testing as of Reporting Date': 15676015,
#    'Total tests completed in the last day': 26643,
#    'Percent positive tests in last day': 1.4,
#    'Under Investigation': 11236,
#    'Number of patients hospitalized with COVID-19': 378,
#    'Number of patients in ICU due to COVID-19': 352,
#    'Number of patients in ICU, testing positive for COVID-19': 293,
#    'Number of patients in ICU, testing negative for COVID-19': 59,
#    'Number of patients in ICU on a ventilator due to COVID-19': 221,
#    'Num. of patients in ICU on a ventilator testing positive': 194,
#    'Num. of patients in ICU on a ventilator testing negative': 27,
#    'Total Positive LTC Resident Cases': 15335,
#    'Total Positive LTC HCW Cases': 7135,
#    'Total LTC Resident Deaths': 3965,
#    'Total LTC HCW Deaths': 10,
#    'Total_Lineage_B.1.1.7_Alpha': 141700,
#    'Total_Lineage_B.1.351_Beta': 1146,
#    'Total_Lineage_P.1_Gamma': 4200,
#    'Total_Lineage_B.1.617.2_Delta': 657,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None},
#   {'_id': 500,
#    'Reported Date': '2021-06-19T00:00:00',
#    'Confirmed Negative': None,
#    'Presumptive Negative': None,
#    'Presumptive Positive': None,
#    'Confirmed Positive': 3871,
#    'Resolved': 529002,
#    'Deaths': 9007,
#    'Deaths_New_Methodology': None,
#    'Total Cases': 541880,
#    'Total patients approved for testing as of Reporting Date': 15701383,
#    'Total tests completed in the last day': 25368,
#    'Percent positive tests in last day': 1.4,
#    'Under Investigation': 9299,
#    'Number of patients hospitalized with COVID-19': 336,
#    'Number of patients in ICU due to COVID-19': 335,
#    'Number of patients in ICU, testing positive for COVID-19': 279,
#    'Number of patients in ICU, testing negative for COVID-19': 56,
#    'Number of patients in ICU on a ventilator due to COVID-19': 221,
#    'Num. of patients in ICU on a ventilator testing positive': 196,
#    'Num. of patients in ICU on a ventilator testing negative': 25,
#    'Total Positive LTC Resident Cases': 15336,
#    'Total Positive LTC HCW Cases': 7135,
#    'Total LTC Resident Deaths': 3965,
#    'Total LTC HCW Deaths': 10,
#    'Total_Lineage_B.1.1.7_Alpha': 141986,
#    'Total_Lineage_B.1.351_Beta': 1154,
#    'Total_Lineage_P.1_Gamma': 4229,
#    'Total_Lineage_B.1.617.2_Delta': 731,
#    'deaths_data_cleaning': None,
#    'newly_reported_deaths': None}],
#  'fields': [{'id': '_id', 'type': 'int'},
#   {'id': 'Reported Date',
#    'type': 'timestamp',
#    'info': {'notes': '', 'type_override': 'timestamp', 'label': ''}},
#   {'id': 'Confirmed Negative',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Presumptive Negative',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Presumptive Positive',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Confirmed Positive',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Resolved',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Deaths',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Deaths_New_Methodology',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total Cases',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total patients approved for testing as of Reporting Date',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total tests completed in the last day',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Percent positive tests in last day',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Under Investigation',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Number of patients hospitalized with COVID-19',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Number of patients in ICU due to COVID-19',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Number of patients in ICU, testing positive for COVID-19',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Number of patients in ICU, testing negative for COVID-19',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Number of patients in ICU on a ventilator due to COVID-19',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Num. of patients in ICU on a ventilator testing positive',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Num. of patients in ICU on a ventilator testing negative',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total Positive LTC Resident Cases',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total Positive LTC HCW Cases',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total LTC Resident Deaths',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total LTC HCW Deaths',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total_Lineage_B.1.1.7_Alpha',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total_Lineage_B.1.351_Beta',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total_Lineage_P.1_Gamma',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'Total_Lineage_B.1.617.2_Delta',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'deaths_data_cleaning',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}},
#   {'id': 'newly_reported_deaths',
#    'type': 'numeric',
#    'info': {'notes': '', 'type_override': 'numeric', 'label': ''}}],
#  '_links': {'start': '/api/3/action/datastore_search?resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=500',
#   'next': '/api/3/action/datastore_search?resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=500&offset=500'},
#  'total': 1151,
#  'total_was_estimated': False}

# %%
# Extract specific columns you are interested in from the dataset
covid_data = data['result']['records']

# %% [markdown]
# on_covid_cases = pd.DataFrame()

# %%
# Convert and store those columns you selected into a dataframe
covid_cases = pd.DataFrame(covid_data)
print(covid_cases)
# Out:
#      _id        Reported Date  Confirmed Negative  Presumptive Negative  \
# 0      1  2020-02-06T00:00:00                 NaN                   NaN
# 1      2  2020-02-07T00:00:00                 NaN                   NaN
# 2      3  2020-02-08T00:00:00                 NaN                   NaN
# 3      4  2020-02-09T00:00:00                 NaN                   NaN
# 4      5  2020-02-10T00:00:00                 NaN                   NaN
# ..   ...                  ...                 ...                   ...
# 495  496  2021-06-15T00:00:00                 NaN                   NaN
# 496  497  2021-06-16T00:00:00                 NaN                   NaN
# 497  498  2021-06-17T00:00:00                 NaN                   NaN
# 498  499  2021-06-18T00:00:00                 NaN                   NaN
# 499  500  2021-06-19T00:00:00                 NaN                   NaN
#
#      Presumptive Positive  Confirmed Positive  Resolved  Deaths  \
# 0                     1.0                 NaN       NaN     NaN
# 1                     2.0                 NaN       NaN     NaN
# 2                     1.0                 1.0       NaN     NaN
# 3                     0.0                 2.0       NaN     NaN
# 4                     0.0                 2.0       NaN     NaN
# ..                    ...                 ...       ...     ...
# 495                   NaN              5012.0  526440.0  8974.0
# 496                   NaN              4662.0  527162.0  8986.0
# 497                   NaN              4390.0  527797.0  8993.0
# 498                   NaN              4110.0  528421.0  8994.0
# 499                   NaN              3871.0  529002.0  9007.0
#
#     Deaths_New_Methodology  Total Cases  ...  \
# 0                     None          NaN  ...
# 1                     None          NaN  ...
# 2                     None          1.0  ...
# 3                     None          2.0  ...
# 4                     None          2.0  ...
# ..                     ...          ...  ...
# 495                   None     540426.0  ...
# 496                   None     540810.0  ...
# 497                   None     541180.0  ...
# 498                   None     541525.0  ...
# 499                   None     541880.0  ...
#
#      Total Positive LTC Resident Cases  Total Positive LTC HCW Cases  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
# ..                                 ...                           ...
# 495                            15332.0                        7129.0
# 496                            15332.0                        7132.0
# 497                            15336.0                        7133.0
# 498                            15335.0                        7135.0
# 499                            15336.0                        7135.0
#
#      Total LTC Resident Deaths  Total LTC HCW Deaths  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
# ..                         ...                   ...
# 495                     3965.0                  10.0
# 496                     3965.0                  10.0
# 497                     3965.0                  10.0
# 498                     3965.0                  10.0
# 499                     3965.0                  10.0
#
#      Total_Lineage_B.1.1.7_Alpha  Total_Lineage_B.1.351_Beta  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ..                           ...                         ...
# 495                     140618.0                      1137.0
# 496                     141106.0                      1141.0
# 497                     141472.0                      1144.0
# 498                     141700.0                      1146.0
# 499                     141986.0                      1154.0
#
#      Total_Lineage_P.1_Gamma  Total_Lineage_B.1.617.2_Delta  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
# ..                       ...                            ...
# 495                   4137.0                            NaN
# 496                   4156.0                          497.0
# 497                   4187.0                          586.0
# 498                   4200.0                          657.0
# 499                   4229.0                          731.0
#
#      deaths_data_cleaning  newly_reported_deaths
# 0                    None                   None
# 1                    None                   None
# 2                    None                   None
# 3                    None                   None
# 4                    None                   None
# ..                    ...                    ...
# 495                  None                   None
# 496                  None                   None
# 497                  None                   None
# 498                  None                   None
# 499                  None                   None
#
# [500 rows x 31 columns]

# %%
# Perform feature engineering on the dataframe we created
covid_cases['reported_date'] = pd.to_datetime(covid_cases['Reported Date'])
covid_cases['new_cases'] = covid_cases['Total Cases'].diff(1)
covid_cases
# Out:
#      _id        Reported Date  Confirmed Negative  Presumptive Negative  \
# 0      1  2020-02-06T00:00:00                 NaN                   NaN
# 1      2  2020-02-07T00:00:00                 NaN                   NaN
# 2      3  2020-02-08T00:00:00                 NaN                   NaN
# 3      4  2020-02-09T00:00:00                 NaN                   NaN
# 4      5  2020-02-10T00:00:00                 NaN                   NaN
# ..   ...                  ...                 ...                   ...
# 495  496  2021-06-15T00:00:00                 NaN                   NaN
# 496  497  2021-06-16T00:00:00                 NaN                   NaN
# 497  498  2021-06-17T00:00:00                 NaN                   NaN
# 498  499  2021-06-18T00:00:00                 NaN                   NaN
# 499  500  2021-06-19T00:00:00                 NaN                   NaN
#
#      Presumptive Positive  Confirmed Positive  Resolved  Deaths  \
# 0                     1.0                 NaN       NaN     NaN
# 1                     2.0                 NaN       NaN     NaN
# 2                     1.0                 1.0       NaN     NaN
# 3                     0.0                 2.0       NaN     NaN
# 4                     0.0                 2.0       NaN     NaN
# ..                    ...                 ...       ...     ...
# 495                   NaN              5012.0  526440.0  8974.0
# 496                   NaN              4662.0  527162.0  8986.0
# 497                   NaN              4390.0  527797.0  8993.0
# 498                   NaN              4110.0  528421.0  8994.0
# 499                   NaN              3871.0  529002.0  9007.0
#
#     Deaths_New_Methodology  Total Cases  ...  Total LTC Resident Deaths  \
# 0                     None          NaN  ...                        NaN
# 1                     None          NaN  ...                        NaN
# 2                     None          1.0  ...                        NaN
# 3                     None          2.0  ...                        NaN
# 4                     None          2.0  ...                        NaN
# ..                     ...          ...  ...                        ...
# 495                   None     540426.0  ...                     3965.0
# 496                   None     540810.0  ...                     3965.0
# 497                   None     541180.0  ...                     3965.0
# 498                   None     541525.0  ...                     3965.0
# 499                   None     541880.0  ...                     3965.0
#
#      Total LTC HCW Deaths  Total_Lineage_B.1.1.7_Alpha  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
# ..                    ...                          ...
# 495                  10.0                     140618.0
# 496                  10.0                     141106.0
# 497                  10.0                     141472.0
# 498                  10.0                     141700.0
# 499                  10.0                     141986.0
#
#      Total_Lineage_B.1.351_Beta  Total_Lineage_P.1_Gamma  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ..                          ...                      ...
# 495                      1137.0                   4137.0
# 496                      1141.0                   4156.0
# 497                      1144.0                   4187.0
# 498                      1146.0                   4200.0
# 499                      1154.0                   4229.0
#
#      Total_Lineage_B.1.617.2_Delta  deaths_data_cleaning  \
# 0                              NaN                  None
# 1                              NaN                  None
# 2                              NaN                  None
# 3                              NaN                  None
# 4                              NaN                  None
# ..                             ...                   ...
# 495                            NaN                  None
# 496                          497.0                  None
# 497                          586.0                  None
# 498                          657.0                  None
# 499                          731.0                  None
#
#      newly_reported_deaths  reported_date  new_cases
# 0                     None     2020-02-06        NaN
# 1                     None     2020-02-07        NaN
# 2                     None     2020-02-08        NaN
# 3                     None     2020-02-09        1.0
# 4                     None     2020-02-10        0.0
# ..                     ...            ...        ...
# 495                   None     2021-06-15      296.0
# 496                   None     2021-06-16      384.0
# 497                   None     2021-06-17      370.0
# 498                   None     2021-06-18      345.0
# 499                   None     2021-06-19      355.0
#
# [500 rows x 33 columns]

# %%
# Perform data cleaning process
relevant_cols = ['reported_date','new_cases']

covid_cases = covid_cases[relevant_cols]
covid_cases['new_cases'].fillna(0, inplace=True)
covid_cases.head(10)
# Out:
#   reported_date  new_cases
# 0    2020-02-06        0.0
# 1    2020-02-07        0.0
# 2    2020-02-08        0.0
# 3    2020-02-09        1.0
# 4    2020-02-10        0.0
# 5    2020-02-11        1.0
# 6    2020-02-12        0.0
# 7    2020-02-13        0.0
# 8    2020-02-14        0.0
# 9    2020-02-15        0.0

# %% [markdown]
# ### Insert data into our database
#
# #### Insert our data into the DataGrip database

# %%
# Insert our data into the DataGrip database
# Just copy paste the following codes and then make adjustments, for example, the name of the dataframe, in the case here
# the name covid_cases can be cahnged to a different one.
my_db_secret = {
    'drivername' : 'postgresql+psycopg2',
    'host'       : 'mmai5100postgres.canadacentral.cloudapp.azure.com',
    'port'       : '5432',
    'username'   : 'kevli88',
    'password'   : '2023!Schulich',
    'database'   : 'kevli88_db'
}

# %%
my_db_url = sa.engine.URL.create(
    drivername = my_db_secret['drivername'],
    username   = my_db_secret['username'],
    password   = my_db_secret['password'],
    host       = my_db_secret['host'],
    port       = my_db_secret['port'],
    database   = my_db_secret['database']
)

# %%
my_db_engine = sa.create_engine(my_db_url)

# %%
# here, name needs to be changed to the name of our dataframe taht we created, dtype should also be changed to the columns we extracted from the dataset from the source website
covid_cases.to_sql(
    name      = 'covid_cases',
    con       = my_db_engine,
    schema    = 'mmai_is_cool',
    if_exists = 'replace',
    index     = False,
    dtype     = {
        'reported_date' : sa.types.DATE,
        'new_cases' : sa.types.DECIMAL(10,0)
    },
    method = 'multi'
)
