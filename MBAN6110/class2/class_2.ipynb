# %%
import pandas as pd

df2 = pd.read_csv("/Users/xinyuanliang/Desktop/MBAN 6110/customers.csv")
df2
# Out:
#       id           cust_name  num_products province  len_relationship  \
# 0   1001      Johnny Awesome             3       ON                 1
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2=df2.rename(columns={"id":"customers_id"})
df2
# Out:
#     customers_id           cust_name  num_products province  len_relationship  \
# 0           1001      Johnny Awesome             3       ON                 1
# 1           1002          Bob Marley             4       ON                 1
# 2           1004        Taylor Swift             2       AB                 2
# 3           1101          James Dean             3       BC                 3
# 4           1006       Stephen Smith             5       ON                 4
# 5           1014       Delilah Avery             2       AB                 3
# 6           1254        Johnson Cory             1       AB                 4
# 7           1285          Maria Alva             5       ON                 2
# 8           1354        Jessica Fast             4       BC                 5
# 9           1005  Mariah Anita Smith             2       BC                 3
# 10          1008      Robert Optimus             3       MB                10
# ...

# %%
df2.set_index('customers_id',inplace=True)

df2.head(10)
df2.tail()
df2.info()
df2.index
df2.columns
df2.axes
df2.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 1001 to 1475
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cust_name         13 non-null     object
#  1   num_products      13 non-null     int64
#  2   province          13 non-null     object
#  3   len_relationship  13 non-null     int64
#  4   cust_category     13 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 624.0+ bytes
# cust_name           object
# num_products         int64
# province            object
# len_relationship     int64
# cust_category       object
# dtype: object

# %%
df2.colums = ['Customers','Num_products','Province','Relationship','Category']
df2
# Out:
# /var/folders/y3/27ykk6jn6d9973zrtpqtdvy40000gn/T/ipykernel_84769/524051024.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df2.colums = ['Customers','Num_products','Province','Relationship','Category']
#                        cust_name  num_products province  len_relationship  \
# customers_id
# 1001              Johnny Awesome             3       ON                 1
# 1002                  Bob Marley             4       ON                 1
# 1004                Taylor Swift             2       AB                 2
# 1101                  James Dean             3       BC                 3
# 1006               Stephen Smith             5       ON                 4
# 1014               Delilah Avery             2       AB                 3
# 1254                Johnson Cory             1       AB                 4
# ...

# %%
df2=df2.rename(columns={'Num_products':'Products'})
df2
# Out:
#                        cust_name  num_products province  len_relationship  \
# customers_id
# 1001              Johnny Awesome             3       ON                 1
# 1002                  Bob Marley             4       ON                 1
# 1004                Taylor Swift             2       AB                 2
# 1101                  James Dean             3       BC                 3
# 1006               Stephen Smith             5       ON                 4
# 1014               Delilah Avery             2       AB                 3
# 1254                Johnson Cory             1       AB                 4
# 1285                  Maria Alva             5       ON                 2
# 1354                Jessica Fast             4       BC                 5
# 1005          Mariah Anita Smith             2       BC                 3
# 1008              Robert Optimus             3       MB                10
# ...

# %%
df2.sort_index(axis=0, ascending=True)
# Out:
#                        cust_name  num_products province  len_relationship  \
# customers_id
# 1001              Johnny Awesome             3       ON                 1
# 1002                  Bob Marley             4       ON                 1
# 1004                Taylor Swift             2       AB                 2
# 1005          Mariah Anita Smith             2       BC                 3
# 1006               Stephen Smith             5       ON                 4
# 1008              Robert Optimus             3       MB                10
# 1014               Delilah Avery             2       AB                 3
# 1101                  James Dean             3       BC                 3
# 1254                Johnson Cory             1       AB                 4
# 1285                  Maria Alva             5       ON                 2
# 1354                Jessica Fast             4       BC                 5
# ...

# %%
list1 = [1,2,3,4]
dictionary1 = {"cust1":"Amy","crust":"John"}

dictionary1["crust"]
# Out:
# 'John'

# %%
df2["Customers"].iloc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customers'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df2["Customers"].loc[1004]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customers'
#
# ...

# %%
type(df2.customers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/y3/27ykk6jn6d9973zrtpqtdvy40000gn/T/ipykernel_52447/3279643284.py in ?()
# ----> 1 type(df2.customers)
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'customers'

# %%
df2[['customers','category']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df2[['customers','category']]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
# ...

# %%
df2.loc[1002]
# Out:
# cust_name                 Bob Marley
# num_products                       4
# province                          ON
# len_relationship                   1
# cust_category       personal_banking
# Name: 1002, dtype: object

# %%
df2.loc[[1002,1001]]
# Out:
#                    cust_name  num_products province  len_relationship
# customers_id
# 1002              Bob Marley             4       ON                 1  \
# 1001          Johnny Awesome             3       ON                 1
#
#                  cust_category
# customers_id
# 1002          personal_banking
# 1001                    wealth

# %%
df2.iloc[4]
# Out:
# cust_name           Stephen Smith
# num_products                    5
# province                       ON
# len_relationship                4
# cust_category                 hnw
# Name: 1006, dtype: object

# %%
df2.iloc[2:4]
# Out:
#                  cust_name  num_products province  len_relationship
# customers_id
# 1004          Taylor Swift             2       AB                 2  \
# 1101            James Dean             3       BC                 3
#
#              cust_category
# customers_id
# 1004                   hnw
# 1101                wealth

# %%
df2.loc[:1101,:'province']
# Out:
#                    cust_name  num_products province
# customers_id
# 1001          Johnny Awesome             3       ON
# 1002              Bob Marley             4       ON
# 1004            Taylor Swift             2       AB
# 1101              James Dean             3       BC

# %%
df2[df2['num_products']==2]
# Out:
#                        cust_name  num_products province  len_relationship
# customers_id
# 1004                Taylor Swift             2       AB                 2  \
# 1014               Delilah Avery             2       AB                 3
# 1005          Mariah Anita Smith             2       BC                 3
# 1475           Stephanie Element             2       ON                 5
#
#                  cust_category
# customers_id
# 1004                       hnw
# 1014          personal_banking
# 1005          personal_banking
# 1475          personal_banking
